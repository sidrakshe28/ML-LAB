# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-67064c00-6905-495d-a70e-ca3381fb66f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67064c00-6905-495d-a70e-ca3381fb66f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-5c2e8a8d365b> in <module>()
#       1 from google.colab import files
# ----> 2 files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...

# %%
import IS_TOOLKIT as tk

# %%
x = b(mod n)
num = n
rem = b
x = ( ∑ (rem[i]*pp[i]*inv[i]) ) % prod
rem[i] is given array of remainders
prod is product of all given numbers
prod = num[0] * num[1] * ... * num[k-1]
pp[i] is product of all divided by num[i]
pp[i] = prod / num[i]
inv[i] Modular Multiplicative Inverse of
/
Enter numbers (n): 3 5 7
Enter remainders (b): 1 4 6
x is 34
inv[i] = Modular Multiplicative Inverse of
 pp[i] with respect to num[i]
"""
def inv(a, m):
 inv_x = tk.egcd(a,m)
 return inv_x[1]
def CRT(num, rem, k) :
 prod = 1
 for i in range(0, k) :
 prod = prod * num[i]
 result = 0
 for i in range(0,k):
 pp = prod // num[i]
 result = result + rem[i] * inv(pp, num[i]) * pp
 return result % prod
num = list(map(int,input("Enter numbers (n): ").split()))
rem = list(map(int,input("Enter remainders (b): ").split()))
k = len(num)
print( "x is " , CRT(num, rem, k))
